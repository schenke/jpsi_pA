# %%
#For more related figures, check out ~/projects/CYM/Derek/plot_v2_pT_rho.ipynb

# %matplotlib notebook
import numpy as np
from numpy import *
from glob import glob
import h5py
import shutil
import os
import sys
from os import path, mkdir
home = path.expanduser("~")
import matplotlib.pyplot as plt
plt.style.use('/Users/schenke/projects/CYM/RpA/csplotstyle')
sys.path.append(os.path.abspath("/Users/schenke/projects/CYM/RpA"))
working_path = path.abspath('/Users/schenke/projects/CYM/Derek/')
from CSplottools import getPlotElements
width = 0.5
plotMarkerSize = 8
left = .03
bottom = .05
right = 0.97
top = 0.95
# Out:
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/pp_Qs0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]

left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.000001,0.1)
ax.set_xlim(0,2)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$dN_{\rm ch}/p_T dp_T dy_g [{\rm GeV}^{-2}]$', fontsize = 20)
ax.plot(data[:,0], data[:,1]/70., alpha=0.6, color='#396AB1', label=r'pp',marker='')

ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/pp_Qs0.5.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMV.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBWn.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBW.dat","r") as f:
    data_temp = genfromtxt(f)    
    data4=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_JPsi_xsec.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]


left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.1,1000)
ax.set_xlim(0,12)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$d\sigma/dY/dP_T ~[\mu{\rm b/GeV}]$', fontsize = 20)
ax.plot(data[:,0], 2*pi*data[:,0]*data[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='#396AB1', label=r'Phip MV 8.16 TeV',marker='')
ax.plot(data2[:,0], 2*pi*data2[:,0]*data2[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='r', label=r'Phip GBW numerical 8.16 TeV',marker='')
ax.plot(data4[:,0], 2*pi*data4[:,0]*data4[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='orange', label=r'Phip GBW 8.16 TeV',marker='',linestyle='--')
ax.errorbar(data3[:,0], data3[:,3], yerr=data3[:,4]+data3[:,6]+data3[:,8], alpha=0.6, color='black', label=r'ALICE 5 TeV',marker='o', linestyle='', linewidth=2)


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/JPsi.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBWPTn.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBWPTlogn.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBWPTlog.dat","r") as f:
    data_temp = genfromtxt(f)    
    data4=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_JPsi_xsec.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]


left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.1,1000)
ax.set_xlim(0,12)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$d\sigma/dY/dP_T ~[\mu{\rm b/GeV}]$', fontsize = 20)
ax.plot(data[:,0], 2*pi*data[:,0]*data[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='#396AB1', label=r'P+T GBW numerical 8.16 TeV',marker='')
ax.plot(data2[:,0], 2*pi*data2[:,0]*data2[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='r', label=r'P+T GBW log numerical 8.16 TeV',marker='')
ax.plot(data4[:,0], 2*pi*data4[:,0]*data4[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='orange', label=r'P+T GBW 8.16 TeV',marker='',linestyle='--')
ax.errorbar(data3[:,0], data3[:,3], yerr=data3[:,4]+data3[:,6]+data3[:,8], alpha=0.6, color='black', label=r'ALICE 5 TeV',marker='o', linestyle='', linewidth=2)


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiGBWPT.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMV.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMVk15.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMVMV.dat","r") as f:
    data_temp = genfromtxt(f)    
    data4=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_JPsi_xsec.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]


left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.1,1000)
ax.set_xlim(0,12)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$d\sigma/dY/dP_T ~[\mu{\rm b/GeV}]$', fontsize = 20)
ax.plot(data[:,0], 2*pi*data[:,0]*data[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='#396AB1', label=r'P MV $\lambda=0.2$ GeV $k<10$ GeV 8.16 TeV',marker='')
ax.plot(data2[:,0], 2*pi*data2[:,0]*data2[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='r', label=r'P MV $\lambda=0.2$ GeV $k<15$ GeV 8.16 TeV',marker='')
ax.plot(data4[:,0], 2*pi*data4[:,0]*data4[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='orange', label=r'P+T MV $\lambda=0.2$ GeV  8.16 TeV',marker='',linestyle='--')
ax.errorbar(data3[:,0], data3[:,3], yerr=data3[:,4]+data3[:,6]+data3[:,8], alpha=0.6, color='black', label=r'ALICE 5 TeV',marker='o', linestyle='', linewidth=2)


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMV.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMVMVlin.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMVMVk25.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMVMV.dat","r") as f:
    data_temp = genfromtxt(f)    
    data4=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_JPsi_xsec.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]


left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(1,1000)
ax.set_xlim(0,12)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$d\sigma/dY/dP_T ~[\mu{\rm b/GeV}]$', fontsize = 20)
ax.plot(data[:,0], 2*pi*data[:,0]*data[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='#396AB1', label=r'P+T MV $\lambda=0.2$ GeV $k<10$ GeV 8.16 TeV',marker='')
ax.plot(data2[:,0], 2*pi*data2[:,0]*data2[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='r', label=r'P+T MV $\lambda=0.2$ GeV $k<25$ GeV 8.16 TeV',marker='')
#ax.plot(data4[:,0], 2*pi*data4[:,0]*data4[:,1]*0.1973*0.1973*10*10**3*0.06, alpha=0.6, color='orange', label=r'P+T MV $\lambda=0.2$ GeV  8.16 TeV',marker='',linestyle='--')
ax.errorbar(data3[:,0], data3[:,3], yerr=data3[:,4]+data3[:,6]+data3[:,8], alpha=0.6, color='black', label=r'ALICE 5 TeV',marker='o', linestyle='', linewidth=2)


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiMV.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/output2.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,20)
ax.set_xlim(0,10)
ax.set_ylabel(r'$J/\Psi dN/y/\langle dN/dy\rangle$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'gluon $dN/\eta/\langle dN/d\eta\rangle$', fontsize = 20)
ax.plot(data[:,0]/data[0,0], data[:,2]/data[0,2], alpha=0.6, color='#396AB1', label=r'p going',marker='')
ax.plot(data[:,0]/data[0,0], data[:,4]/data[0,4], alpha=0.6, color='r', label=r'Pb going',marker='')

x = np.linspace(0,10,100)
ax.plot(x, x, '-r', color='gray', label='', linestyle=":")

ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
ax.text(right, bottom, 'p+Pb 8.16 TeV',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/scaling.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/outputQs.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,16)
ax.set_xlim(0,5)
ax.set_ylabel(r'normalized yield', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$Q_s^p$ factor', fontsize = 20)
ax.plot(data[:6,6], data[:6,0]/data[0,0], alpha=0.6, color='#396AB1', label=r'gluons',marker='')
ax.plot(data[:6,6], data[:6,2]/data[0,2], alpha=0.6, color='orange', label=r'$J/\Psi$ p going',marker='')
ax.plot(data[:6,6], data[:6,4]/data[0,4], alpha=0.6, color='r', label=r'$J/\Psi$ Pb going',marker='')
ax.plot(data[6:12,6], data[6:12,0]/data[0,0], alpha=0.6, color='#396AB1', label=r'',marker='',linestyle="--")
ax.plot(data[6:12,6], data[6:12,2]/data[0,2], alpha=0.6, color='orange', label=r'',marker='',linestyle="--")
ax.plot(data[6:12,6], data[6:12,4]/data[0,4], alpha=0.6, color='r', label=r'',marker='',linestyle="--")
ax.plot(data[12:18,6], data[12:18,0]/data[0,0], alpha=0.6, color='#396AB1', label=r'',marker='',linestyle=":")
ax.plot(data[12:18,6], data[12:18,2]/data[0,2], alpha=0.6, color='orange', label=r'',marker='',linestyle=":")
ax.plot(data[12:18,6], data[12:18,4]/data[0,4], alpha=0.6, color='r', label=r'',marker='',linestyle=":")

x = np.linspace(0,10,100)
#ax.plot(x, x, '-r', color='gray', label='', linestyle=":")

ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
ax.text(right, bottom, 'p+Pb 8.16 TeV',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/Qsdep.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = [(1, 1, 1), (0, 0.1, 0.8), (0, 0.5, 0.6),(0.1,0.7,0.5),(0.5,0.9,0.4),(0.9,0.8,0),(0.9,0.44,0),(0.93,0,0),(0.5,0,0)]  # R -> G -> B
n_bins = 1000  # Discretizes the interpolation into bins
cmap_name = 'my_list'

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/TA.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
N=200    
x = reshape(data[:,0],(N,N))
y = reshape(data[:,1],(N,N))
TA = reshape(data[:,2],(N,N))

left = .03
bottom = .05
right = 0.97
top = 0.95

cm = LinearSegmentedColormap.from_list(cmap_name, colors, N=n_bins)
fig = plt.figure(figsize=(8,8), dpi=100)
ax = plt.axes([0.15, 0.15, 0.82, 0.82])

#ax.get_yaxis().set_ticks([-4,-3,-2,-1,0,1,2,3,4])
#ax.get_xaxis().set_ticks([-4,-3,-2,-1,0,1,2,3,4])

ax.set_ylim(-10,10)
ax.set_xlim(-10,10)

ax.set_xlabel(r'$x\,[{\rm fm}]$', fontsize = 32)
ax.set_ylabel(r'$y\,[{\rm fm}]$', fontsize = 32, labelpad=-4)

# ax.tick_params(axis='x', which='both', bottom=True, top=True, direction='in') #,pad=8
# ax.tick_params(axis='y', which='both', left=True, right=True, direction='in')
# ax.tick_params(axis='x', which='both', bottom=True, top=True, direction='in')
# ax.tick_params(axis='y', which='both', left=True, right=True, direction='in')

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(32)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(32)
    

levels = linspace(0, amax(TA), 1000)
ax.contourf(x, y, (TA), 1000, cmap=cm, zorder=-20,levels=levels)
ax.set_rasterization_zorder(-10)


plt.tight_layout()
#plt.savefig('./TA.pdf')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/matplotlib/figure.py:1999: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputHy-5.dat","r") as f:
#with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputBig_y10.dat","r") as f:
#with open("/Users/schenke/projects/pAJPsi/JPsi/output_h_0.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputGy-5.dat","r") as f:
#with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputBig_y10.dat","r") as f:
#with open("/Users/schenke/projects/pAJPsi/JPsi/output_0.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,9)
ax.set_xlim(0,7)
ax.set_ylabel(r'$N_{J/\psi}/\langle N_{J/\psi}\rangle$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$N_g/\langle N_g\rangle$', fontsize = 20)
x = np.linspace(0,10,100)
ax.plot(x, x, '-r', color='gray', label='', linestyle=":")
ax.scatter(data[:,0]/mean(data[:,0]), data[:,2]/mean(data[:,2]), alpha=0.5, c='b', label=r'p going',marker='s',s=5)
ax.scatter(data[:,0]/mean(data[:,0]), data[:,4]/mean(data[:,4]), alpha=0.5, c='r', label=r'Pb going',marker='o',s=5)

ax.scatter(data2[:,0]/mean(data2[:,0]), data2[:,2]/mean(data2[:,2]), alpha=0.4, c='g', label=r'p going',marker='s',s=5)
ax.scatter(data2[:,0]/mean(data2[:,0]), data2[:,4]/mean(data2[:,4]), alpha=0.4, c='y', label=r'Pb going',marker='o',s=5)



print("<Nh> = ",mean(data[:,0]))
print("<Ng> = ",mean(data2[:,0]))
print("<NJPsi> p going = ",mean(data[:,2]))
print("<NJPsi> Pb going = ",mean(data[:,4]))


#ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=2, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
ax.text(right, bottom, 'p+Pb 8.16 TeV',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)

# ax.text(/
right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)


plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/scatter.pdf')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# <Nh> =  21.839684181818182
# <Ng> =  10.952586294258374
# <NJPsi> p going =  0.009018414570813397
# <NJPsi> Pb going =  0.009026265003827753

# %%
fig2c = plt.figure()
fig2c.set_size_inches(7,5)
ax = plt.axes()
ax.hist(data[:,0]/mean(data[:,0]), bins=[0.2,0.4,0.6,0.8,1.,1.2,1.4,1.6,1.8,2.,2.2,2.4,2.6,2.8,3.,3.2,3.4,3.6,3.8,4], log=True, density=True, alpha=0.6, label=r'hadrons')
ax.hist(data2[:,0]/mean(data2[:,0]),bins=[0.2,0.4,0.6,0.8,1.,1.2,1.4,1.6,1.8,2.,2.2,2.4,2.6,2.8,3.,3.2,3.4,3.6,3.8,4], log=True, density=True, alpha=0.6, label=r'gluons')
ax.legend(loc=1, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
ax.set_ylabel(r'$P(N_g/\langle N_g\rangle)$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$N_g/\langle N_g\rangle$', fontsize = 20)
plt.tight_layout()
#ax.hist(data[:,0])
#print((array(data[:,0])))
#print(sort(array(data[:,0])))
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
fig2c = plt.figure()
fig2c.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,8)
ax.set_xlim(0,8)
#ax.hist(data[:,0], log=True)

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_p-going_8160GeV_2004.12673.dat","r") as f:
    data_temp = genfromtxt(f)    
    dataALICEp=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_Pb-going_8160GeV_2004.12673.dat","r") as f:
    data_temp = genfromtxt(f)    
    dataALICEPb=data_temp[:,:]


gluons = data[:,0]/mean(data[:,0])
jpsip = data[:,2]/mean(data[:,2])
jpsiPb = data[:,4]/mean(data[:,4])

gluons2 = data2[:,0]/mean(data2[:,0])
jpsip2 = data2[:,2]/mean(data2[:,2])
jpsiPb2 = data2[:,4]/mean(data2[:,4])
ax.set_ylabel(r'$N_{J/\psi}/\langle N_{J/\psi}\rangle$', fontsize = 20)

ax.set_xlabel(r'$N_g/\langle N_g\rangle$', fontsize = 20)
bins = linspace(0, 8, 24)
digitized = digitize(gluons, bins)
bin_means = [(jpsip[digitized == i]).mean() for i in range(0, len(bins))]
bin_means2 = [(jpsiPb[digitized == i]).mean() for i in range(0, len(bins))]
digitizedb = digitize(gluons2, bins)
bin_meansb = [(jpsip2[digitizedb == i]).mean() for i in range(0, len(bins))]
bin_meansb2 = [(jpsiPb2[digitizedb == i]).mean() for i in range(0, len(bins))]
x = np.linspace(0,10,100)
print(bins)
plotbins = bins+(bins[1]-bins[0])/2.
ax.plot(x, x, '-r', color='gray', label='', linestyle=":")

ax.errorbar(dataALICEp[:,0], dataALICEp[:,3], yerr=dataALICEp[:,4], alpha=0.5, color='black', label=r'ALICE p-going',marker='o', linestyle='', linewidth=1)
ax.errorbar(dataALICEp[:,0], dataALICEp[:,3], yerr=dataALICEp[:,6], alpha=0.3, color='black', label=r'',marker='', linestyle='', linewidth=3)

ax.errorbar(dataALICEPb[:,0], dataALICEPb[:,3], yerr=dataALICEPb[:,4], alpha=0.5, color='black', label=r'ALICE Pb-going',marker='s', linestyle='', linewidth=1)
ax.errorbar(dataALICEPb[:,0], dataALICEPb[:,3], yerr=dataALICEPb[:,6], alpha=0.3, color='black', label=r'',marker='', linestyle='', linewidth=3)


ax.step(bins, bin_means, alpha=0.8, color='#396AB1', label=r'p going hadrons',marker='')
ax.step(bins, bin_means2, alpha=0.8, color='r', label=r'Pb going hadrons',marker='')
#ax.step(bins, bin_meansb, alpha=0.8, color='g', label=r'p going gluons',marker='')
#ax.step(bins, bin_meansb2, alpha=0.8, color='y', label=r'Pb going gluons',marker='')




ax.legend(loc=2, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">
# [0.         0.34782609 0.69565217 1.04347826 1.39130435 1.73913043
#  2.08695652 2.43478261 2.7826087  3.13043478 3.47826087 3.82608696
#  4.17391304 4.52173913 4.86956522 5.2173913  5.56521739 5.91304348
#  6.26086957 6.60869565 6.95652174 7.30434783 7.65217391 8.        ]
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: Mean of empty slice.
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: Mean of empty slice.
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:32: RuntimeWarning: Mean of empty slice.
# ...

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/Jpsiy.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/Jpsiyfast.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2c = plt.figure()
fig2c.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,2000)
ax.set_xlim(-5,5)
ax.set_ylabel(r'$(d\sigma/dy)/2 [\mu b]$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$y$', fontsize = 20)
ax.plot(data[:,0], data[:,5], alpha=0.6, c='b', label=r'',marker='s',linestyle='')
ax.plot(data2[:,0], data2[:,3], alpha=0.6, c='r', label=r'',marker='o',linestyle='')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputpre0.5y9.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputpre0.4y9.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/cori/outputpre0.8y9.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]
    
    
fig2d = plt.figure()
fig2d.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,8)
ax.set_xlim(0,8)
#ax.hist(data[:,0], log=True)

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_p-going_8160GeV_2004.12673.dat","r") as f:
    data_temp = genfromtxt(f)    
    dataALICEp=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/ALICE_Pb-going_8160GeV_2004.12673.dat","r") as f:
    data_temp = genfromtxt(f)    
    dataALICEPb=data_temp[:,:]


gluons = data[:,0]/mean(data[:,0])
jpsip = data[:,2]/mean(data[:,2])
jpsiPb = data[:,4]/mean(data[:,4])

gluons2 = data2[:,0]/mean(data2[:,0])
jpsip2 = data2[:,2]/mean(data2[:,2])

gluons3 = data3[:,0]/mean(data3[:,0])
jpsip3 = data3[:,2]/mean(data3[:,2])

ax.set_ylabel(r'$N_{J/\psi}/\langle N_{J/\psi}\rangle$', fontsize = 20)
ax.set_xlabel(r'$N_g/\langle N_g\rangle$', fontsize = 20)
bins = linspace(0, 8, 24)
digitized = digitize(gluons, bins)
bin_means = [(jpsip[digitized == i]).mean() for i in range(0, len(bins))]
bin_means2 = [(jpsiPb[digitized == i]).mean() for i in range(0, len(bins))]

digitized2 = digitize(gluons2, bins)
bin_means_04 = [(jpsip2[digitized2 == i]).mean() for i in range(0, len(bins))]

digitized3 = digitize(gluons3, bins)
bin_means_06 = [(jpsip3[digitized3 == i]).mean() for i in range(0, len(bins))]

x = np.linspace(0,10,100)



plotbins = bins+(bins[1]-bins[0])/2.
ax.plot(x, x, '-r', color='gray', label='', linestyle=":")

ax.errorbar(dataALICEp[:,0], dataALICEp[:,3], yerr=dataALICEp[:,4], alpha=0.5, color='black', label=r'ALICE p-going',marker='o', linestyle='', linewidth=1)
ax.errorbar(dataALICEp[:,0], dataALICEp[:,3], yerr=dataALICEp[:,6], alpha=0.3, color='black', label=r'',marker='', linestyle='', linewidth=3)

#ax.errorbar(dataALICEPb[:,0], dataALICEPb[:,3], yerr=dataALICEPb[:,4], alpha=0.5, color='black', label=r'ALICE Pb-going',marker='s', linestyle='', linewidth=1)
#ax.errorbar(dataALICEPb[:,0], dataALICEPb[:,3], yerr=dataALICEPb[:,6], alpha=0.3, color='black', label=r'',marker='', linestyle='', linewidth=3)



ax.step(bins, bin_means_04, alpha=0.8, color='r', label=r'$Q_s$ prefactor 0.4, y=9',marker='')
ax.step(bins, bin_means, alpha=0.8, color='g', label=r'$Q_s$ prefactor 0.5, y=9',marker='')
ax.step(bins, bin_means_06, alpha=0.8, color='b', label=r'$Q_s$ prefactor 0.8, y=9',marker='')


ax.legend(loc=2, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:44: RuntimeWarning: Mean of empty slice.
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Mean of empty slice.
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:48: RuntimeWarning: Mean of empty slice.
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/ipykernel_launcher.py:51: RuntimeWarning: Mean of empty slice.

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/hadronsEta.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/data/CMS_pPb_Nch_vs_eta.dat","r") as f:
    data_temp = genfromtxt(f)    
    dataCMS=data_temp[:,:]
    
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2c = plt.figure()
fig2c.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,30)
ax.set_xlim(-8,8)
ax.set_ylabel(r'$dN/dy$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$y {\rm~or~} \eta$', fontsize = 20)
ax.plot(data[:,0], data[:,1]/27*20, alpha=0.6, c='orange', label=r'hadrons (normalized later)',marker='o',linestyle='')
ax.plot(data[:,0], data[:,2]/27*20, alpha=0.6, c='b', label=r'gluons (normalized like hadrons)',marker='s',linestyle='')
ax.errorbar(dataCMS[:,0], dataCMS[:,3], yerr=dataCMS[:,4], alpha=0.3, color='black', label=r'CMS',marker='o', linestyle='', linewidth=1)
ax.errorbar(dataCMS[:,0], dataCMS[:,3], yerr=dataCMS[:,6], alpha=0.3, color='black', label=r'',marker='', linestyle='', linewidth=3)
ax.legend(loc=2, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
fig2e = plt.figure()
fig2e.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,1500)
ax.set_xlim(-8,8)
ax.set_ylabel(r'$d\sigma/dy [\mu b]$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$y$', fontsize = 20)
ax.plot(data[:,0], 0.06*data[:,3]*2061*1000, alpha=0.6, c='r', label=r'Jpsi',marker='o',linestyle='')

ax.text(right, bottom, 'F=0.06',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/Jpsiy-new.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
    
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2e = plt.figure()
fig2e.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,800)
ax.set_xlim(-8,8)
ax.set_ylabel(r'$d\sigma/dy [\mu b]$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$y$', fontsize = 20)
ax.plot(data[:,0], 0.02*data[:,1]*2061*1000, alpha=0.6, c='r', label=r'Jpsi',marker='o',linestyle='')
ax.text(right, bottom, 'F=0.02',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">
