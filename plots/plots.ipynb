# %%
#For more related figures, check out ~/projects/CYM/Derek/plot_v2_pT_rho.ipynb

# %matplotlib notebook
import numpy as np
from numpy import *
from glob import glob
import h5py
import shutil
import os
import sys
from os import path, mkdir
home = path.expanduser("~")
import matplotlib.pyplot as plt
plt.style.use('/Users/schenke/projects/CYM/RpA/csplotstyle')
sys.path.append(os.path.abspath("/Users/schenke/projects/CYM/RpA"))
working_path = path.abspath('/Users/schenke/projects/CYM/Derek/')
from CSplottools import getPlotElements
width = 0.5
plotMarkerSize = 8
left = .03
bottom = .05
right = 0.97
top = 0.95
# Out:
# /Users/schenke/projects/yt-conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/pp_Qs0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]

left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.000001,0.1)
ax.set_xlim(0,2)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$dN_{\rm ch}/p_T dp_T dy_g [{\rm GeV}^{-2}]$', fontsize = 20)
ax.plot(data[:,0], data[:,1]/70., alpha=0.6, color='#396AB1', label=r'pp',marker='')

ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/pp_Qs0.5.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiAllQspQsA.dat","r") as f:
    data_temp = genfromtxt(f)    
    data=data_temp[:,:]
    
with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiAll.dat","r") as f:
    data_temp = genfromtxt(f)    
    data2=data_temp[:,:]

with open("/Users/schenke/projects/pAJPsi/JPsi/plots/JPsiSSQspQsA.dat","r") as f:
    data_temp = genfromtxt(f)    
    data3=data_temp[:,:]


left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0.000001,1000)
ax.set_xlim(0,8)
ax.set_xlabel(r'$p_T [{\rm GeV}]$', fontsize = 20)
ax.set_yscale('log')
ind = np.arange(5)
ax.set_ylabel(r'$d\sigma/dY/dP_T [\mu{\rm b/GeV}]$', fontsize = 20)
ax.plot(data[:,0], data[:,0]*data[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='#396AB1', label=r'Qsp QsA',marker='')
#ax.plot(data2[:,0], data2[:,0]*data2[:,1]*0.1973*0.1973*10*10**3., alpha=0.6, color='r', label=r'all terms',marker='')
ax.plot(data3[:,0], data3[:,0]*data3[:,1]*0.1973*0.1973*10*10**3.*0.06, alpha=0.6, color='orange', label=r'SS term',marker='', linewidth=2)


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=0, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
# ax.text(left, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
#         horizontalalignment='left',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/pAJPsi/JPsi/plots/JPsi.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
with open("/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/etas_0.08/momentum_anisotropy_eta_-0.5_0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data_ep=data_temp[:,:]
    
with open("/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/etas_0/momentum_anisotropy_eta_-0.5_0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data_ep_0=data_temp[:,:]
    
with open("/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/etas_0_0.08/momentum_anisotropy_eta_-0.5_0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data_ep_0_008=data_temp[:,:]
    
with open("/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/linear/momentum_anisotropy_eta_-0.5_0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data_ep_l=data_temp[:,:]
    
with open("/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/quadratic/momentum_anisotropy_eta_-0.5_0.5.dat","r") as f:
    data_temp = genfromtxt(f)    
    data_ep_q=data_temp[:,:]

left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,0.4)
ax.set_xlim(0,9)
ax.set_ylabel(r'$\varepsilon_p$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$\tau[{\rm fm}]$', fontsize = 20)
ax.plot(data_ep[2:,0], sqrt(data_ep[2:,5]**2+data_ep[2:,6]**2), alpha=0.6, color='#396AB1', label=r'$\eta/s=0.08$',marker='')
ax.plot(data_ep_0[2:,0], sqrt(data_ep_0[2:,5]**2+data_ep_0[2:,6]**2), alpha=0.8, color='#DD6A39', label=r'$\eta/s=0$',marker='',linestyle="--")
ax.plot(data_ep_0_008[2:,0], sqrt(data_ep_0_008[2:,5]**2+data_ep_0_008[2:,6]**2), alpha=0.8, color='green', label=r'$\eta/s=0.01$ for 1 fm, then 0.08',marker='',linestyle="--")
#ax.plot(data_ep_l[2:,0], sqrt(data_ep_l[2:,5]**2+data_ep_l[2:,6]**2), alpha=0.8, color='black', label=r'linear rise to 0.08 at 1fm Pb+Pb 5.02 TeV 40-50\%',marker='',linestyle="-.")
ax.plot(data_ep_q[2:,0], sqrt(data_ep_q[2:,5]**2+data_ep_q[2:,6]**2), alpha=0.8, color='purple', label=r'quadratic rise to 0.08 at 1fm',marker='',linestyle=":")




ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=1, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
ax.text(right, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/ep_vs_tau.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
left = .03
bottom = .05
right = 0.97
top = 0.95

fig2b = plt.figure()
fig2b.set_size_inches(7,5)
ax = plt.axes()
ax.set_ylim(0,0.4)
ax.set_xlim(0,9)
ax.set_ylabel(r'$\varepsilon_p^{\rm ideal}$', fontsize = 20)
ind = np.arange(5)
ax.set_xlabel(r'$\tau[{\rm fm}]$', fontsize = 20)
ax.plot(data_ep[2:,0], sqrt(data_ep[2:,1]**2+data_ep[2:,2]**2), alpha=0.6, color='#396AB1', label=r'$\eta/s=0.08$',marker='')
ax.plot(data_ep_0[2:,0], sqrt(data_ep_0[2:,1]**2+data_ep_0[2:,2]**2), alpha=0.8, color='#DD6A39', label=r'$\eta/s=0$',marker='',linestyle="--")
ax.plot(data_ep_0_008[2:,0], sqrt(data_ep_0_008[2:,1]**2+data_ep_0_008[2:,2]**2), alpha=0.8, color='green', label=r'$\eta/s=0.01$ for 1 fm, then 0.08',marker='',linestyle="--")
ax.plot(data_ep_q[2:,0], sqrt(data_ep_q[2:,1]**2+data_ep_q[2:,2]**2), alpha=0.8, color='purple', label=r'quadratic rise to 0.08 at 1fm',marker='',linestyle=":")


ax.axhline(y=0, linewidth=1, color='black', linestyle=':')
ax.legend(loc=1, prop={'size': 16}, ncol=1, fontsize=16, frameon=False)
plt.tight_layout()
ax.text(right, bottom, 'Pb+Pb 5.02 TeV 40-50\%',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes, fontsize = 20)

# ax.text(right, bottom, 'a)',
#         horizontalalignment='right',
#         verticalalignment='bottom',
#         transform=ax.transAxes, fontsize = 20)

plt.savefig('/Users/schenke/projects/HYDRO/music_dev/MUSIC/evolution_files/ep_vs_tau_ideal.pdf') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
